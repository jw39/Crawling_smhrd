# %% [markdown]
# # Requests 라이브러리
# - 파이썬 코드를 통해서 웹페이지의 정보를 요청해주는 라이브러리 -> 브라우저 역할 대신

# %%
import requests as req

# %%
# 1. 네이버 페이지 좀 가져와줘!
# req 요청을 보내면 response 응답이 넘어온다.
# 응답 코드 200 ->통신에 성공했습니다.
# 응답 코드 400 -> 에러 (클라이언트의 요청의 문제) -> 요청을 수정하면 통신에 성공 // JAVA Script 문제
# 응답 코드 500 -> 에러 (서버의 응답 문제) -> 접근이 불가능 // DB, JSP 문제
res = req.get("http://www.naver.com")

# %%
# 2. 응답코드 속에서 html 정보만 조회
res.text
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_240502.css"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>\nwindow["EAGER-DATA"] = window["EAGER-DATA"] || {};\nwindow["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","excludeInPaging":false,"positionForPaging":0,"realtime":false,"filterList":[{"id":"ALL","name":"전체","defaultType":true},{"id":"BEST","name":"인기","defaultType":true},{"id":"ANIMAL","name":"동물","defaultType":false},{"id":"TRAVEL","name":"여행","defaultType":false},{"id":"WEDDING","name":"연애결혼","defaultType":false},{"id":"MOVIE","name":"영화","defaultType":false},{"id":"MOMKIDS","name":"육아","defaultType":false}],"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@code":"PC-FEED-RECOMMEND-FILTER-TAB","@template":"PC-FEED-RECOMMEND-FILTER-TAB"},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"주말예능 전참시 최강희 ADHD 검사 의심되서 받았더니 결과 진짜!?","url":"https://in.naver.com/thom/contents/internal/690483147668000","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fdiscovercrop-phinf.pstatic.net%2F%2FMjAyNDA1MDVfODUg%2FMDAxNzE0ODgyNTEwODIw.EF6JxbPHnma1t_29VMaAWaLfi-en6IEKIUkxCDvY04kg.NcwAfkRtf4TPfk8jU4OqdFGwnU_60MfxkFUt0FpWiDIg.JPEG%2Fimage_750x420.jpg%22&type=nf365_240&service=navermain"},"source":{"url":"https://blog.naver.com/chesungmin","name":"Tom편집장","service":"BLOG","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAxNjEwMjlfMjI3%2FMDAxNDc3NzQ2ODE0NTU0.cHkLuuQqRmNu3ZLxYPpNyz6_1Sy6XlLfuhB_Bfoxt-cg.EWVIvw_nmhzVAefhyP22cGQ1fJaLN4tBkmRc9q-hRhwg.PNG.chesungmin%2Ftom.PNG%22&type=nf96_96&service=navermain"}},"labels":[{"type":"category","text":""}],"showLiveBadge":false,"_id":"6441ca92c499cc07f334c46b"},{"@type":"MATERIAL-PC-FEED","title":"소개팅서 \'얼굴값하면 거르자\' 생각했는데...섬세함에 반했죠","url":"https://blog.naver.com/sum-lab/223435011924","image":{"url":"https://s.pstatic. ...

# %% [markdown]
# # BeautifulSoup 라이브러리
# - req로 받아온 텍스트 데이터를 컴퓨터가 이해할 수 있게 html로 변형해주는 라이브러리

# %%
from bs4 import BeautifulSoup as bs

# %%
# bs을 통해서 text -> html 변형 => 파싱 작업
# bs 객체화를 진행한다!
soup = bs(res.text, "lxml")
# lxml -> 파싱 형태
# Out:
# <!DOCTYPE html>
# <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="알파벳a 주가 : 네이버 통합검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'알파벳a 주가'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'알파벳a 주가'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>알파벳a 주가 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240314.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_240502.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_240502.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.styl ...
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=sit_45p*e.kep&amp;r=0&amp;i=a00000fa_9f5f4604d09ce520db8f9202&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://kr.investing.com/equities/google-inc" onclick='goOtherCR(this,"a=sit_45p*e.link&amp;r=0&amp;i=a00000fa_9f5f4604d09ce520db8f9202&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fkr.investing.com%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://kr.investing.com/equities/google-inc" target="_blank">
# kr.investing.com<i class="divide">›</i>equities</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="https://kr.investing.com/equities/google-inc" onclick='goOtherCR(this,"a=sit_45p*e.link&amp;r=0&amp;i=a00000fa_9f5f4604d09ce520db8f9202&amp;u="+urlencode(this.href))' target="_blank"><mark>알파벳</mark> <mark>주식</mark> | GOOGL - Investing.com - 인베스팅닷컴</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https://kr.investing.com/equities/google-inc" onclick='goOtherCR(this,"a=sit_45p*e.link&amp;r=0&amp;i=a00000fa_9f5f4604d09ce520db8f9202&amp;u="+urlencode(this.href))' target="_blank"><mark>주가</mark>, 차트, 기술적 분석, 역사적 자료 및 <mark>알파벳</mark> 보고서 등을 포함한 <mark>알파벳</mark>(GOOGL) <mark>주식</mark>에 대한 자세한 정보를 확인하세요.</a></div></div></div><div class="source_cluster_wrap"><div class="source_cluster_list"><div class="source_item"><a class="source_title" href="https://kr.investing.com/equities/google-inc-dividends" onclick='goOtherCR(this,"a=sit_45p*e.link&amp;r=1&amp;i=a00000fa_635fd47974663acc8d76025a%5El&amp;u="+urlencode(this.href))' target="_blank"><mark>알파벳 A</mark> <mark>주식</mark> 배당 기록- Investing.com - 인베스팅닷컴</a><div class="source_dsc"><mark>알파벳 A</mark>에 대한 상세한 배당일과 배당 발표 정보를 확인하세요.</div></div></div></div><div class="total_more_wrap"><a class="total_more" href="?query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80+site%3Akr.investing.com&amp;qvt=0&amp;where=web" onclick='goOtherCR(this,"a=sit_45p*e.sramore&amp;r=&amp;i=&amp;u="+urlencode(this.href))'>관련문서 더보기<i class="spnew api_ico_arr4"></i></a></div></li></ul></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/commonPortal/pc_240116.js",t=function(){var t=window.require.config({context:"_fe_web_commonportal",paths:{Controller:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["Controller"],function(e){var t=jQuery("._fe_root_sit_45pd"),n=new e(t);n.on({"tab-scroll":function(e){e.isTrusted},"content-scroll":function(e){if(e.isTrusted){var t=e.$wrapper.find("._freescroll_flicking").attr("data-log");t&&tCR(t)}},"click-infolayer-trigger-button":function(e){e.isOn}})})},n=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:n,t,!0,150)})()</script><script>(function(){var e,n="_sp_ntotal",s="type_margin",t=Array.prototype.slice.call(document.querySelectorAll("section."+n));function o(e,t){return e.matches?e.matches(t):!!e.msMatchesSelector&&e.msMatchesSelector(t)}function i(e){var t=e,s=t.tagName.toLowerCase();do t=t.previousElementSibling,s=t?t.tagName.toLowerCase():"";while(t!==null&&(s==="script"||s==="link"))return t!==null&&s==="section"&&o(t,"."+n)}for(e=0;e<t.length;++e)i(t[e])&&t[e].classList.add(s)})()</script><div class="_scrollLog" data-slog-id="sit_45p*e" style="visibility:hidden;height:0px;margin:0 28px"></div><section class="sc_new sp_nnews _prs_nws_all"> <div class="api_subject_bx"> <div class="mod_title_area"> <div class="title_wrap"> <h2 class="title">뉴스</h2> </div> <div class="title_sub"> <a aria-selected="true" class="sub_option" href="?where=news&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a%20%EC%A3%BC%EA%B0%80&amp;sort=0&amp;sm=tab_smr&amp;nso=so:r,p:all,a:all" onclick="return goOtherCR(this, 'a=nws_all.sortsim&amp;u='+urlencode(this.href));" role="option">관련도순</a> <a class="sub_option" href="?where=news&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a%20%EC%A3%BC%EA%B0%80&amp;sort=1&amp;sm=tab_smr&amp;nso=so:dd,p:all,a:all" onclick="return goOtherCR(this, 'a=nws_all.sortdate&amp;u='+urlencode(this.href));" role="option">최신순</a> <div class="news_option _press_option_wrap"> <a aria-pressed="false" class="api_switch _press_option_switch" href="?query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;service_area=1&amp;sm=tab_smr&amp;sort=0&amp;where=news&amp;nso=so:r,p:all,a:all" onclick="return goOtherCR(this, 'a=nws_all.sortm&amp;u='+urlencode(this.href));" role="button">모바일 메인 언론사<i class="spnew ico_switch"></i></a> <div class="spnew_bf n ...
# 경제 전문블로거 31명</span></a></div><div class="flick_bx"><a aria-pressed="false" class="mod_tag" href="?query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;where=influencer&amp;x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22173947046844960%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" onclick="return goOtherCR(this,'a=ink_kiz*f.maintheme&amp;r=&amp;i=&amp;g=K_173947046844960&amp;u='+urlencode(this.href))" role="button"><span class="t"><span class="thumb"><img alt="" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMTAyMjZfNTMg%2FMDAxNjE0MzA3MTIxOTE0.NFDsqf05NdlzmoVRKaN3Hgu_p-qSFAqxpcTjQp3sNnYg.4OsiFOQ4NHDZhxNLswZ0vYC7_b2hzryxfhBlb7IjoWMg.JPEG%2FprofileImage.jpg&amp;type=f76_76" height="28" src="..." width="28"/></span>
# 투자 분석가 5명</span></a></div><div class="flick_bx"><a aria-pressed="false" class="mod_tag" href="?query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;where=influencer&amp;x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22241108303322432%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" onclick="return goOtherCR(this,'a=ink_kiz*f.maintheme&amp;r=&amp;i=&amp;g=K_241108303322432&amp;u='+urlencode(this.href))" role="button"><span class="t"><span class="thumb"><img alt="" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMTAxMjhfMTc5%2FMDAxNjExODI0MDE2NjA4.dg2J77TY0sdHZajsdR3_cF_h1Gr0MmdUjF2cGx8SN1kg.rCvlV41IqckC-y3mbYn7PgMoE-5i0oREPfYdJiPFwrMg.JPEG%2F20191120_170528565.jpg&amp;type=f76_76" height="28" src="..." width="28"/></span>
# 자산운용 전문가 2명</span></a></div><div class="flick_bx"><a aria-pressed="false" class="mod_tag" href="?query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;where=influencer&amp;x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22241108303363392%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" onclick="return goOtherCR(this,'a=ink_kiz*f.maintheme&amp;r=&amp;i=&amp;g=K_241108303363392&amp;u='+urlencode(this.href))" role="button"><span class="t"><span class="thumb"><img alt="" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fhomebuilder-phinf.pstatic.net%2FMjAyMjAxMjVfMjYw%2FMDAxNjQzMDUzMTA3ODI5.hO4eeW5QKQgQW-2OvfXVU-WQ5RiD3yO39tjk0S8XeWog.75px1VnOIbca6WA5Sl_CXvz5AR_hMmxV423IjOzBzFEg.JPEG%2F1643053107771_D71B12E7-8896-41E9-9DA5-632089DE219B.jpeg&amp;type=f76_76" height="28" src="..." width="28"/></span>
# 비즈니스 매거진 에디터 1명</span></a></div></div><div class="api_btn_page"><div class="btn_prev _scroll_prev" style="display:none;"><a class="btn" href="#" role="button"><i class="spnew ico_arr">이전</i></a></div><div class="btn_next _scroll_next" style="display:none;"><a class="btn" href="#" role="button"><i class="spnew ico_arr">다음</i></a></div></div></div></div><div class="challenge_wrap"><ul class="keyword_challenge_list _inf_contents"><li class="keyword_bx _item _check_visible" data-alarm-name="류짱" data-containment="" data-fan-off-click-id="ink_kiz*a.fanoff" data-fan-on-click-id="ink_kiz*a.fanon" data-list-index="0" data-myfeed-link="https://in.naver.com/myfeed?filterSpaceId=525737114217504&amp;selectedSpaceId=525737114217504" data-space-id="525737114217504"><div class="keyword_box_wrap"><div class="user_box"><div class="user_box_inner"><a class="user_thumb_wrap" href="https://in.naver.com/ryujjang?areacode=ink*a&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80" onclick="return goOtherCR(this,'a=ink_kiz*a.profile&amp;r=1&amp;i=a0209rl4_nblog_post_223430720147&amp;u='+urlencode(this.href))" target="_blank"><span class="badge _fe_badge_fan" style="display:none;"><i class="spinf_af ico_badge">팬</i></span>
# <span class="badge type_gold _fe_badge_rank"><i class="spinf_af ico_badge">금</i></span><div class="user_thumb"><img alt="" class="img" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fblogpfthumb-phinf.pstatic.net%2FMjAyMjAyMjNfMjIg%2FMDAxNjQ1NjE5NDgzMjkz.IUQn3cHdpYkoR2zxEG0a2kry04jVsCG1uBtBCGRqn3Yg.FUA89WJBy_OzJRn1UA9LnOLhSFld_POS3HoHqliHnHgg.PNG.poslee777%2F%25ED%2594%2584%25EB%25A1%259C%25ED%2595%2584%25EC%259D%25B4%25EB%25AF%25B8%25EC%25A7%2580-001.png%2F%25ED%2594%2584%25EB%25A1%259C%25ED%2595%2584%25EC%259D%25B4%25EB%25AF%25B8%25EC%25A7%2580-001.png&amp;type=f96_96" height="36" src="..." width="36"/></div></a><div class="user_info"><div class="user_area"><a class="name elss" href="https://in.naver.com/ryujjang?areacode=ink*a&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80" onclick="return goOtherCR(this,'a=ink_kiz*a.nickname&amp;r=1&amp;i=a0209rl4_nblog_post_223430720147&amp;u='+urlencode(this.href))" target="_blank"><span class="txt">류짱</span></a>
# <span class="fan_count">팬 <span class="_fan_count">3,791</span></span></div><div class="etc_area"><span class="etc">경제 전문블로거</span>
# <span class="etc">주식/펀드 전문</span></div></div><div class="btn_area"><a aria-pressed="false" class="btn_fan _fan_button" data-home-url="https://in.naver.com/ryujjang?areacode=ink*a&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80" href="#" role="button"><div class="base"><div class="container"><svg class="smile" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd" id="Page-1" stroke="none" stroke-width="1"><
xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd" id="Page-1" stroke="none" stroke-width="1"><path d="M9.456 8.224V.256H8.124v3.06H7.308V.448H6V7.852H7.308V4.456H8.124V8.224H9.456zM5.424 2.368V1.24H.492V2.368H5.424zM.396 6.808c1.68-.024 4.14-.168 5.304-.348L5.592 5.38C5.34 5.428 4.98 5.476 4.56 5.512 4.644 4.66 4.74 3.82 4.836 2.956 4.416 2.92 3.984 2.872 3.564 2.824l-.216 2.76L2.604 5.62 2.472 2.812l-1.356.18.276 2.664C1.02 5.668.624 5.668.228 5.668.276 6.052.336 6.424.396 6.808zm9.3 3.876V9.568H3.504V7.348H2.1v3.336H9.696z" fill-rule="nonzero" id="팬"></path></g></svg></div></div></a><div class="spinf_bf mod_ly_notice _tooltip_first_fan_visit" style="display:none;"><strong>내가 팬한 인플루언서</strong>의 글이 먼저 보여집니다!</div><div class="spinf_bf mod_ly_notice _tooltip_first_visit" style="display:none;">마음에 든다면 <strong>팬</strong>이 되어보세요!</div></div></div><div class="my_keyword_area _area_expand"><ul class="my_type_overview"><li class="keyword"><span class="txt short"><strong class="hlt">블로그 이웃 7,300+</strong></span></li><li class="keywor ...
# <a aria-pressed="false" class="btn_option _button_toggle_alarm" href="#" role="button"><i class="spinf ico_alarm_off">OFF</i>
# <i class="spinf ico_alarm_on">ON</i></a></div><a class="btn_item spinf_af ico_fan_arr _fe_my_feed" href="#">나의 피드 바로가기</a></div></div><a class="popup_close _button_close" href="#"><span class="spinf ico_info_close">닫기</span></a></div><div class="popup_alarm type_on _section_fan_info" style="display: none;"><div class="tit"><div class="name_wrap"><div class="name_bx"><div class="name _name"></div><div class="txt">님의 팬입니다!</div></div></div><div class="desc"><div class="name_bx"><div class="txt">검색 결과에서</div><div class="name _name"></div><div class="txt">님의 콘텐츠가 우선적으로 보일 수 있습니다.</div></div></div><div class="desc">팬 한 인플루언서의 콘텐츠는 나의 피드에서 모아볼 수 있어요.</div></div><div class="fan_btn_area"><div class="fan_btn_inner"><div class="btn_bx"><strong class="tit_sub">네이버 알림</strong>
# <a aria-pressed="false" class="btn_option _button_toggle_alarm" href="#" role="button"><i class="spinf ico_alarm_off">OFF</i>
# <i class="spinf ico_alarm_on">ON</i></a></div><a class="btn_item spinf_af ico_fan_arr _fe_my_feed" href="#">나의 피드 바로가기</a>
# <a class="btn_item btn_cancel _button_unsubscribe" href="#">팬하기 취소</a></div></div><a class="popup_close _button_close" href="#"><span class="spinf ico_info_close">닫기</span></a></div></div><div class="api_popup_capcha _fe_influencer_captcha_layer" style="display: none;"><div class="popup_capcha _fe_influencer_captcha_root"><p class="dsc_area"><strong class="tit">자동 팬하기를 방지하기 위해 보안 절차를 거치고 있습니다.</strong>
# <em class="txt">아래 문자를 보이는 대로 입력해주세요.</em></p><div class="code_area _fe_influencer_captcha_code_area"><div class="code_bx"><img class="img _fe_influencer_captcha_code_image" height="91" src="" width="200"/><div class="guide"><i class="spnew ico_capcha_voice2"></i>
# <em class="txt">음성으로 안내되고 있습니다<br/>시작음 3회 반복 후 재생</em></div></div><div class="btn_bx"><a class="btn_refresh _fe_influencer_captcha_code_refresh_button" href="#" onclick="tCR('a=ink_kiz.cabre&amp;r=&amp;i=&amp;u=javascript')"><i class="spnew ico_capcha_refresh">새로고침</i></a>
# <a class="btn_voice _fe_influencer_captcha_code_voice_button" href="#" onclick="tCR('a=ink_kiz.cabvoice&amp;r=&amp;i=&amp;u=javascript')"><i class="spnew ico_capcha_voice">음성으로 듣기</i></a>
# <a class="btn_image _fe_influencer_captcha_code_image_button" href="#" onclick="tCR('a=ink_kiz.cabimg&amp;r=&amp;i=&amp;u=javascript')"><i class="spnew ico_capcha_img">이미지로 보기</i></a></div></div><div class="input_area _fe_influencer_captcha_input_area"><span class="input_inner"><input class="input_code _fe_influencer_captcha_input_code" placeholder="자동입력방지문자"/></span>
# <button class="btn_submit _fe_influencer_captcha_input_submit_button" onclick="tCR('a=ink_kiz.cabin&amp;r=&amp;i=&amp;u=javascript')">확인</button>
# <span class="etc _fe_influencer_captcha_input_etc" style="display: none">다시 입력해주세요</span></div><a class="popup_close _fe_influencer_captcha_input_close_button" href="#" onclick="tCR('a=ink_kiz.cabclose&amp;r=&amp;i=&amp;u=javascript')"><span class="spnew ico_info_close">닫기</span></a></div></div></section><section class="sc_new sp_influencer type_nogap _fe_influencer_toast_section"><div class="api_modal_toast _fe_influencer_toast_root" style="display: none;"><a class="btn_toast spnew_af disabled" href="javascript:;"><div class="dsc_area"><em class="dsc">더이상 <strong class="name _fe_influencer_toast_name"></strong>님의 팬이 아닙니다.</em><div class="dsc_sub">이제 알림을 받지 않습니다.</div></div></a></div></section><script>(function(){var a=function(){window.require.config({context:"ugc",paths:{InfluencerPortalPC:"https://ssl.pstatic.net/sstatic/fe/sfe/ugc/influencer-pc/InfluencerPortalPC_230921.js".replace(/\.js$/,"")}})(["InfluencerPortalPC"],function(b){var c=document.getElementById("_section_influencer"),d=["pc","portal"],a=new b({store:{isEnd:!0},commonUI:{url:{homeSubscribeUrl:"https://gw.in.naver.com/home/api/v3/spaces/{=spaceId}/subscribes",homeUnsubscribeUrl:"https://gw.in.naver.com/home/api/v3/spaces/{=spaceId}/unsubscribes",homeMySubscribes:"https://gw.in.naver.com/delivery/api/v1/subscribes?spaceIds=",homeStatistics:"https://gw.in.naver.com/delivery/api/v1/space-statistics?spaceIds=",notiSubscribeSettingUrl:"https://gw.in.naver.com/notification/api/v1/spaces/{=spaceId}/subscribe-notification-setting",notiMySubscribeUrl:"https://gw.in.naver.com/notification/api/v1/spaces/{=spaceId}/my-subscribe-notification-setting",loginUrl:"https://nid.naver.com/nidlogin.login?svctype=262144&url=",imageCaptchaUrl:"https://captcha.nid.naver.com/nhncaptchav4.gif?key={=key}&{=timestamp}",voiceCaptchaUrl:"https://soundcaptcha.nid.naver.com/soundCaptcha.wav?key={=key}&replay={=replay}",captchaConfirmUrl:"https://gw.in.naver.com/identity-access/api/v1/captcha",captchaChangeUrl:"https://gw.in.naver.com/identity-access/api/v1/captcha?type={=type}&expireKey={=expireKey}&expireType={=expireType}",captchaRefreshUrl:"https://gw.in.naver.com/identity-access/api/v1/refresh-captcha?key={=key}&type={=type}",talktalkUrl:"https://gw.in.naver.com/home/api/v1/spaces/{=spaceId}/talktalk-url",errorRedirectUrl:"",lottieUrl:"https://ssl.pstatic.net/sstatic/au/m/influencer/asset/lottie.min.js"}},contents:{listIndex:0},dimensions:d,forYouConfig:{url:"https://s.search.naver.com/p/influencer/46/api/v1/airs",params:{where:"api",q:"알파벳a 주가",q_gdid:"",prev_clicked_gdids:"",search_result_gdids:"",abt:"",area:""},areaType:{keywordChallenge:"ink_kiz*n",result:"ink_kiz*N"},displayPosition:"collection",persistId:"_fe_inf_foryou_clicked_gdid",storage:{key:"_fe_inf_foryou_prev_clicked_gdids",duration:15*60*1e3,count:10},countForSRG:5}});a.on({"change-fan":function(a){tCR('a='+a.clickId+'&r=&i=&u=javascript')},"change-alarm":function(a){a.isAlarmOn?tCR('a=ink_kiz.alimon&r=&i=&u=javascript'):tCR('a=ink_kiz.alimoff&r=&i=&u=javascript')},crossDisplay:function(c){for(var b=(c.$collection.attr("data-cr-item")||"").split("|").filter(function(a){return!!a}),a=0;a<b.length;++a)tCR("a="+b[a])},"show-foryou":function(a){a.length&&window.naver&&window.naver.common&&window.naver.common.responsiveLog&&window.naver.common.responsiveLog.send&&window.naver.common.responsiveLog.send(a)}}),a.mount(c)})},b="https://ssl.pstatic.net/sstatic/au/module/requirejs/require-2.3.5.js";nhn.common.load_js(window.require?null:b,a,!0,150)})()</script><div class="_scrollLog" data-slog-id="ink_kiz*af" style="visibility:hidden;height:0px;margin:0 28px"></div><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_nreview_240201.css" rel="stylesheet" type="text/css"/> <section class="sc_new sp_nreview _fe_view_root _prs_ugB_bsR"> <div class="api_subject_bx"> <div class="mod_title_area"> <div class="title_wrap"> <h2 class="title">비즈니스·경제 인기글</h2> </div> </div> <ul class="lst_view"> <li class="bx"> <div class="view_wrap">  ...
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=web_gen*w.kep&amp;r=0&amp;i=90000003_0000000000000033FC2B7C8C%5EG&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://blog.naver.com/dkals357/223274040460" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=0&amp;i=90000003_0000000000000033FC2B7C8C%5EG&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fblog.naver.com%2Ffavicon.ico%3F3&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://blog.naver.com/dkals357/223274040460" target="_blank">
# blog.naver.com<i class="divide">›</i>dkals357</a></div></div></div><div class="total_group"><div class="thumb_single _parent"><a class="thumb_link" href="https://blog.naver.com/dkals357/223274040460" onclick='goOtherCR(this,"a=web_gen*w.simg&amp;r=0&amp;i=90000003_0000000000000033FC2B7C8C%5EG&amp;u="+urlencode(this.href))' target="_blank"><img alt="" class="img api_get" data-img-alias="hide" data-img-eparam="._parent" data-lazysrc="https://search.pstatic.net/common?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzExMjRfMjU2%2FMDAxNzAwODI5OTc0MjEy.sasssU0lqtdGyi8tGWwP4Zk7VbmMHpca_IyW_9S7HXAg.iDCrkwsxgszW_YwQEep56oJGDgA1Kn_eAfk7uB42CdMg.JPEG.dkals357%2F%25C1%25A6%25B8%25F1%25C0%25BB-%25C0%25D4%25B7%25C2%25C7%25D8%25C1%25D6%25BC%25BC%25BF%25E4_-001.jpg&amp;type=fff208_208" height="104" src="..." width="104"/></a></div><div class="total_tit"><a class="link_tit" href="https://blog.naver.com/dkals357/223274040460" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=0&amp;i=90000003_0000000000000033FC2B7C8C%5EG&amp;u="+urlencode(this.href))' target="_blank"><mark>알파벳 A</mark> <mark>주식</mark> <mark>주가</mark>전망 &amp; 구글 <mark>주식</mark> 실적 알아봐요!</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https
onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=2&amp;i=90000003_0000000000000033D664F9AD%5EG&amp;u="+urlencode(this.href))' target="_blank"><span class="dsc_sub"><span class="sub_txt">2022.02.06.</span></span>
# <mark>알파벳</mark> Class <mark>A 주가</mark>와 <mark>알파벳</mark> Class C <mark>주가</mark>의 차이점에 대해 알아보도록하겠습니다. <mark>알파벳</mark> 구글 미국 <mark>주식</mark>에 관심있으신 주린이 분들 중 구글 <mark>주식</mark>을 사고 싶은데 <mark>알파벳</mark>이 나와 당황하시는 분들도 있으실 것 같습니다. <mark>알파벳</mark>은 구글의 모회사입니다. 1998년 구글이 창립되었으나 구글이 자율주행자동차, 유튜브, 헬스케어 등 여러분야로 사업이 확장되며 보다... <mark>알파벳</mark><mark>주가</mark>...</a></div></div></div></li></ul><div class="mod_more_wrap"><a class="group_more" href="?nso=&amp;page=2&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=web_gen*w.more2&amp;r=&amp;i=&amp;u="+urlencode(this.href))'><span class="kwd">검색결과</span>
# <span class="etc">더보기<i class="spnew ico_arr"></i></span></a></div></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/commonPortal/pc_240116.js",t=function(){var t=window.require.config({context:"_fe_web_commonportal",paths:{Controller:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["Controller"],function(e){var t=jQuery("._fe_root_web_gend"),n=new e(t);n.on({"tab-scroll":function(e){e.isTrusted},"content-scroll":function(e){if(e.isTrusted){var t=e.$wrapper.find("._freescroll_flicking").attr("data-log");t&&tCR(t)}},"click-infolayer-trigger-button":function(e){e.isOn}})})},n=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:n,t,!0,150)})()</script><script>(function(){var e,n="_sp_ntotal",s="type_margin",t=Array.prototype.slice.call(document.querySelectorAll("section."+n));function o(e,t){return e.matches?e.matches(t):!!e.msMatchesSelector&&e.msMatchesSelector(t)}function i(e){var t=e,s=t.tagName.toLowerCase();do t=t.previousElementSibling,s=t?t.tagName.toLowerCase():"";while(t!==null&&(s==="script"||s==="link"))return t!==null&&s==="section"&&o(t,"."+n)}for(e=0;e<t.length;++e)i(t[e])&&t[e].classList.add(s)})()</script><div class="_scrollLog" data-slog-id="web_gen*w" style="visibility:hidden;height:0px;margin:0 28px"></div><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_nkin_240227.css" rel="stylesheet"/><section class="sc_new sp_nkin _fe_kin_collection"><div class="api_subject_bx"><div class="mod_title_area"><div class="title_wrap"><h2 class="title">지식iN</h2></div></div><ul class="lst_nkin"><li class="bx"><div class="kin_wrap"><div class="question_area"><i class="spnew api_ico_q">Q</i><div class="question_group"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=kin*k.kep&amp;r=1&amp;i=10000009_000018814417&amp;u=javascript" data-cr-on="a=kin*k.kep&amp;r=1&amp;i=10000009_000018814417&amp;u=javascript" data-url="https://kin.naver.com/qna/detail.naver?dirId=40102&amp;docId=411124759" href="javascript;" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="kin*k.kepoff&amp;r=1&amp;i=10000009_000018814417&amp;u=javascript" data-cr-on="kin*k.kepon&amp;r=1&amp;i=10000009_000018814417&amp;u=javascript" href="javascript;" role="button">Keep에 저장
# ...
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=q1GBrtT7FRxjWX8iCcJC4f///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000294488092&amp;d='+urlencode('http://www.kiwoom.com')+'&amp;u='+urlencode(this.href));" target="_blank">키움증권</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=q1GBrtT7FRxjWX8iCcJC4f///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000294488092&amp;d='+urlencode('http://www.kiwoom.com')+'&amp;u='+urlencode(this.href));" target="_blank">kiwoom.com</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=q1GBrtT7FRxjWX8iCcJC4f///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000294488092&amp;d=' + urlencode('http://www.kiwoom.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">키움 미국수수료 완전무료0원</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=q1GBrtT7FRxjWX8iCcJC4f///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=2&amp;i=nad-a001-01-000000294488092&amp;d=' + urlencode('http://www.kiwoom.com') + '&amp;u='+ urlencode(this.href));" target="_blank">신규&amp;휴면 3개월 미국주식 거래수수료 0원, 환전우대 최대 95% 최대500만원 받고 키움으로 해외주식 옮기기</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=KH6T2IQ+Ne21hbqAZrwBZv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=2&amp;i=nad-a001-01-000000294488092&amp;d='+urlencode('http://www.kiwoom.com')+'&amp;u='+urlencode(this.href));" target="_blank">나스닥토탈뷰</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=bgNsXIqArrADNlmudiwKrf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=2&amp;i=nad-a001-01-000000294488092&amp;d='+urlencode('http://www.kiwoom.com')+'&amp;u='+urlencode(this.href));" target="_blank">미국수수료0</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=YoxjXCwD3nctQrcB+To9If///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=2&amp;i=nad-a001-01-000000294488092&amp;d='+urlencode('http://www.kiwoom.com')+'&amp;u='+urlencode(this.href));" target="_blank">$33받기</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=ZYX+vaM8vAh0nocZ5RFhnf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=2&amp;i=nad-a001-01-000000294488092&amp;d='+urlencode('http://www.kiwoom.com')+'&amp;u='+urlencode(this.href));" target="_blank">주식옮기기</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_link type_img" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=0jWnMsGrsl2CxaS9zXyUbv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d='+urlencode('https://www.onestopsamsungpop.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMzA0MDVfNTcg/MDAxNjgwNjYwOTQxMzEx.X1gBDVK18QG1qn3AvnVsmQZFF6sKbMnUPuAvfqCgrCAg.Hic4e8Sb6cob3qlYxXTeg-spo-Wzc3BxgekLDxUqefog.JPEG/2007160-a7a11766-655e-469d-854f-87c350d0190e.jpg?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=2oW8+ncJuxJd4c1Ser2xdf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d='+urlencode('https://www.onestopsamsungpop.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.samsungpop.com%2Fimages%2Fcommon%2Flogo.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=2oW8+ncJuxJd4c1Ser2xdf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d='+urlencode('https://www.onestopsamsungpop.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">삼성증권</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=2oW8+ncJuxJd4c1Ser2xdf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d='+urlencode('https://www.onestopsamsungpop.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">onestopsamsungpop.co.kr</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=2oW8+ncJuxJd4c1Ser2xdf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d=' + urlencode('https://www.onestopsamsungpop.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">현명한 관리의 시작 삼성증권</span><span class="lnk_tit">수수료 혜택 확인</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=2oW8+ncJuxJd4c1Ser2xdf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d=' + urlencode('https://www.onestopsamsungpop.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">종목 정보 찾으시나요? 삼성증권 mPOP에서 투자정보를 참고하세요</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=RrVL/T7MomYeg5FOKbt7Zv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d='+urlencode('https://www.onestopsamsungpop.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">최대$100</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=W0lj3iDyjnB6iryfns5QlP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d='+urlencode('https://www.onestopsamsungpop.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">수수료혜택</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=YM+7UwXrLqqdF7K9mTnps////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d='+urlencode('https://www.onestopsamsungpop.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">환율환전혜택</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=p6hMXANBFN8dTzZSeq4rD////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000281045948&amp;d='+urlencode('https://www.onestopsamsungpop.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">앱다운로드</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# <div class="mod_more_wrap">
# <a class="group_more" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a%EC%A3%BC%EA%B0%80&amp;referenceId=iBVLelqo1fsssclGDmNssssstW8-027531&amp;bucketTest=impression-neo-118&amp;bucket=1" onclick="return goOtherCR(this, 'a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u='+urlencode(this.href));" target="_blank">
# <span class="etc">더보기<i class="spnew ico_arr"></i></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     (function () {
#       var createPlaceImageConveyer = function () {
#         var prev = document.getElementById("_place_prev_button");
#         var next = document.getElementById("_place_next_button");
#         if (prev == null || next == null) {
#           return;
#         }
#         prev.style.display = "none";
#         var require = window.require.config({
#           context: "impression_neo_place_extension",
#           paths: {
#             "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#           }
#         });
#         require(["egjsConveyer"], function (egjsConveyer) {
#           var conveyer = new egjsConveyer("#place_flicking", {autoInit: false, preventClickOnDrag: true});
#
#
#           conveyer.subscribe("isReachStart", function (isReachStart) {
#             prev.style.display = isReachStart ? "none" : "block";
#           });
#
#           conveyer.subscribe("isReachEnd", function (isReachEnd) {
#             next.style.display = isReachEnd ? "none" : "block";
#           });
#           conveyer.init();
#
#           if (!conveyer.isReachEnd) {
#             next.style.display = "block";
#           }
#
#           prev.addEventListener("click", function () {
#             conveyer.scrollIntoView("start", {
#               align: "end",
#               duration: 500,
#               excludeStand: true,
#             });
#           });
#           next.addEventListener("click", function () {
#             conveyer.scrollIntoView("end", {
#               align: "start",
#               duration: 500,
#               excludeStand: true,
#             });
#           });
#         });
#       };
#       nhn.common.load_js(null, createPlaceImageConveyer, true, 150);
#     })();
#   </script>
# <div class="_scrollLog" data-slog-id="pwl_nop" style="visibility:hidden;height:0px;margin:0 28px"></div><div class="api_sc_page_wrap"><div class="sc_page"><a aria-disabled="true" class="btn_prev" role="button"><i class="spnew api_ico_pg_arr">이전</i></a><div class="sc_page_inner"><a aria-pressed="true" class="btn" href="?nso=&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;where=nexearch" onclick='goOtherCR(this,"a=pag.pag&amp;r=1&amp;i=&amp;u="+urlencode(this.href))' role="button">1</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=2&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=2&amp;i=&amp;u="+urlencode(this.href))' role="button">2</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=3&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=3&amp;i=&amp;u="+urlencode(this.href))' role="button">3</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=4&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=4&amp;i=&amp;u="+urlencode(this.href))' role="button">4</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=5&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=5&amp;i=&amp;u="+urlencode(this.href))' role="button">5</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=6&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=6&amp;i=&amp;u="+urlencode(this.href))' role="button">6</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=7&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=7&amp;i=&amp;u="+urlencode(this.href))' role="button">7</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=8&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=8&amp;i=&amp;u="+urlencode(this.href))' role="button">8</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=9&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=9&amp;i=&amp;u="+urlencode(this.href))' role="button">9</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=10&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=10&amp;i=&amp;u="+urlencode(this.href))' role="button">10</a></div><a aria-disabled="false" class="btn_next" href="?nso=&amp;page=11&amp;query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=11&amp;i=&amp;u="+urlencode(this.href))' role="button"><i class="spnew api_ico_pg_arr">다음</i></a></div></div><div class="_scrollLogEndline" style="visibility:hidden;height:0px"></div></div><div class="sub_pack" id="sub_pack"><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_viewer_231214.css" rel="stylesheet"/><section class="sc_new sp_viewer type_sub _fe_image_viewer_root" style="display: none;"></section><script>var imageSearchViewerModulePaths={ImageSearchViewer:"https://ssl.pstatic.net/sstatic/fe/sfe/image-search/pc-viewer/ImageSearchViewer_240426.js".replace(/\.js$/,"")},imageSearchViewerServerPaths={relatedImagesAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026aq=0\u0026json_type=11\u0026mode=related\u0026nlu_query=%7B%22r_category%22%3A%2233%22%7D\u0026nqx_theme=%7B%22theme%22%3A%7B%22main%22%3A%7B%22name%22%3A%22finance%22%2C%22score%22%3A%220.852032%22%7D%7D%7D\u0026nx_search_query=%EC%95%8C%ED%8C%8C%EB%B2%B3a\u002b%EC%A3%BC%EA%B0%80\u0026query=%EC%95%8C%ED%8C%8C%EB%B2%B3a\u002b%EC%A3%BC%EA%B0%80\u0026where=image",singlePhotoAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026json_type=10\u0026where=image",reportAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?json_type=2\u0026query=%EC%95%8C%ED%8C%8C%EB%B2%B3a\u002b%EC%A3%BC%EA%B0%80",lensAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?json_type=16\u0026mode=\u0026query=%EC%95%8C%ED%8C%8C%EB%B2%B3a\u002b%EC%A3%BC%EA%B0%80\u0026vintageid=\u0026where=image"}</script><script>(function(){var a=function(){var a=window.require.config({context:"image-search-viewer",paths:{ImageSearchViewer:imageSearchViewerModulePaths.ImageSearchViewer}});define("jquery",[],function(){return jQuery}),a(["ImageSearchViewer"],function(a){var b={target:"#sub_pack",root:"._fe_image_viewer_root",focusTarget:"._fe_image_viewer_focus_target"},c={lensViewer:{lensAPI:{url:imageSearchViewerServerPaths.lensAPIUrl+"&p_nvmid={=nvmid}&articleid={=articleid}&parentid={=parentid}&querySource={=querySource}&from={=from}&sbiid={=sbiid}&lensThumb={=lensThumb}"}},viewer:{singlePhotoAPI:{url:imageSearchViewerServerPaths.singlePhotoAPIUrl+"&imgId={=imgId}"},relatedImagesAPI:{url:imageSearchViewerServerPaths.relatedImagesAPIUrl+"&imgId={=imgId}&p_signature={=signature}&p_nvmid={=nvmid}&articleid={=articleid}&lensThumb={=lensThumb}&querySource={=querySource}&start={=start}",max:50},keepAPI:{dataUrl:"https://search.naver.com/search.naver?mode=column\u0026query=%EC%95%8C%ED%8C%8C%EB%B2%B3a\u002b%EC%A3%BC%EA%B0%80\u0026where=image"},shoppingZzimAPI:{check:"https://s.search.naver.com/p/image/46/search.naver?where=zzim&zzim_type=zzimcheck&zzim_info={=info}",create:"https://s.search.naver.com/p/image/46/search.naver?where=zzim&&zzim_type=zzimadd&zzim_info={=info}",delete:"https://s.search.naver.com/p/image/46/search.naver?where=zzim&zzim_type=zzimdel&zzim_info={=info}",loginUrl:"https://nid.naver.com/nidlogin.login?svctype=262144&url={=location}"},reportAPI:{url:imageSearchViewerServerPaths.reportAPIUrl+"&imgId={=imgId}",reportUrl:"https://s.search.naver.com/n/srm/report"}},mode:"portal"},d=new a({selectors:b,context:c});window.naver=window.naver||{},window.naver.common=window.naver.common||{},window.naver.common.imageSearchViewer=d,window.naver.common.imageSearchViewer.start()})},b="https://ssl.pstatic.net/sstatic/au/module/requirejs/require-2.3.5.js";nhn.common.load_js(window.require?null:b,a,!0,100)})()</script><section class="sc_new sp_related" id="nx_right_related_keywords"> <div ...

# %% [markdown]
# # 뉴스의 타이틀 정보만 수집

# %%
# 1. 데이터 요청
res = req.get("https://search.naver.com/search.naver?where=nexearch&sm=top_sly.hst&fbm=0&acr=1&acq=%EC%95%8C%ED%8C%8C%EB%B2%B3+&qdt=0&ie=utf8&query=%EC%95%8C%ED%8C%8C%EB%B2%B3a+%EC%A3%BC%EA%B0%80")

# %%
# 2. bs 데이터로 파싱 작업 해주기
soup = bs(res.text, 'lxml')

# %%
# 3. sopu 데이터 중 뉴스 타이틀만 수집해줘
# soup 데이터 중에 a 태그만 수집해줘
# 특정 요소를 수집하기 위해서 select 명령어 활용
# 주의점 : select 명령어가 복수개를 의미 -> 리턴 데이터가 리스트 형태로 넘어온다.
# 반드시 인덱스를 활용해야 데이터 접근이 가능함
# 하나만 수집하고 싶은 경우 -> select_one()
title = soup.select("a.news_tit")

# %%
# 3. 순수한 텍스트 데이터만 새롭게 생성
# 엘리먼트 요소들을 가져온 것이니 컨텐츠를 꺼내와야함
# title[0].text 이걸 반복하고, 반복 후 빈 리스트에 가져온 텍스트를 담을 거야
titleList = []
for i in title :
    # 글자만 꺼내서 비어있는 리스트에 저장
    titleList.append(i.text)

# %%
titleList
# Out:
# ['[미국주식] 증시 혼조…MS·엔비디아·테슬라·디즈니 등 주가↓ 알파벳은↑',
#  '[미국주식] 증시 아직 ‘땡큐’ 연준…애플·알파벳·엔비디아·아마존 등 주...',
#  "미국증시 나스닥100 상승...테슬라 '폭등', 애플 '급등', 알파벳A '뚝'",
#  '[미국주식] 증시, 머스크 핫이슈…테슬라·애플·아마존 등 주가↑, MS·메타...']

# %% [markdown]
# # 크롤링할 때 기억해야 하는 순서
# 1) 수집하고자 하는 사이트의 정보를 요청 -> req.get(url)
# 2) bs를 통해서 데이터를 html로 변형 -> 컴퓨터가 접근할 수 있게
# 3) select 함수를 통해서 필요한 요소만 수집 -> soup.select("선택자")
# 4) 순수하게 필요한 정보(글자, 속성)만 재가공 -? 비어있는 리스트 제작
# 5) 데이터를 활용 -> 데이터 프레임을 통한 시각화, csv 파일로 저장, 머신러닝, 딥러닝의 학습 데이터로의 활용
